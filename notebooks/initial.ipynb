# %%
# Clone your repo (first time only)
# !git clone https://github.com/pranjalbainsla/mini-llm.git
# %cd mini-llm

# %%
# Install dependencies
# !pip install -r requirements.txt

# %%
# Download dataset (or upload your own)
# !wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt -O data/input.txt

# %%
# Train
# !python train.py

# %%
# Generate
# !python generate.py
